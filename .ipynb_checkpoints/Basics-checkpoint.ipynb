# %%
print("hello world") # basic printing
# Out:
# hello world

# %%
# variables and Numbers
variable = "john" # str
variable2 = 1 # int
variable2 = variable

# %%
decimal_number = 1.0
print(type(decimal_number))
# Out:
# <class 'float'>

# %%
print(variable)
print(variable2)
# print(variable + variable2) # error handling
print(type(variable)) # str
print(type(variable2)) # str
# Out:
# john
# john
# <class 'str'>
# <class 'str'>

# %%
var = "hello" # immutable
var2 = "world"
var2 = var
var[0] = "W"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 4
#       2 var2 = "world"
#       3 var2 = var
# ----> 4 var[0] = "W"
#
# TypeError: 'str' object does not support item assignment

# %%
var = [1, 2, 3] # list # mutable
var[0] = 99
print(var)
immutable_list = (1, 2, 3) # tuple # immutable
immutable_list[1] = 99
# Out:
# [99, 2, 3]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[22], line 5
#       3 print(var)
#       4 immutable_list = (1, 2, 3) # tuple # immutable
# ----> 5 immutable_list[1] = 99
#
# TypeError: 'tuple' object does not support item assignment

# %%
a = 1 # int

if type(a) == int:
    print("hello")
    print("hello2")
# Out:
# hello
# hello2

# %% [markdown]
# # keywords and softkeywords in python
# # spaces in python
# 1. strings
# 2. lists
# 3. tuples
# 4. int and float

# %% [markdown]
# # my name is John
